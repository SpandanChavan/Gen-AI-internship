# %% [markdown]
# ## Prodigy Infotech Task 5
# ##### Neural Style Transfer

# %%
# import numpy, tensorflow and matplotlib
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import math

# import VGG 19 model and keras Model API
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Model

# %%
# Image Credits: Tensorflow Doc
content_path = tf.keras.utils.get_file(
'content.jpg',
'https://storage.googleapis.com/download.tensorflow.org/example_images/YellowLabradorLooking_new.jpg')
style_path = tf.keras.utils.get_file(
'style.jpg',
'https://storage.googleapis.com/download.tensorflow.org/example_images/Vassily_Kandinsky%2C_1913_-_Composition_7.jpg')
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/YellowLabradorLooking_new.jpg
# 83281/83281 [==============================] - 0s 2us/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/Vassily_Kandinsky%2C_1913_-_Composition_7.jpg
# 195196/195196 [==============================] - 0s 2us/step

# %%
# code to load and process image
def load_and_process_image(image_path):
	img = load_img(image_path)
	# convert image to array
	img = img_to_array(img)
	img = preprocess_input(img)
	img = np.expand_dims(img, axis=0)
	return img

# %%
# code
def deprocess(img):
	# perform the inverse of the pre processing step
	img[:, :, 0] += 103.939
	img[:, :, 1] += 116.779
	img[:, :, 2] += 123.68
	# convert RGB to BGR
	img = img[:, :, ::-1]

	img = np.clip(img, 0, 255).astype('uint8')
	return img


def display_image(image):
	# remove one dimension if image has 4 dimension
	if len(image.shape) == 4:
		img = np.squeeze(image, axis=0)

	img = deprocess(img)

	plt.grid(False)
	plt.xticks([])
	plt.yticks([])
	plt.imshow(img)
	return

# %%
# load content image
content_img = load_and_process_image(content_path)
display_image(content_img)

# load style image
style_img = load_and_process_image(style_path)
display_image(style_img)

# %%
# code
# this function download the VGG model and initialise it
model = VGG19(
	include_top=False,
	weights='imagenet'
)
# set training to False
model.trainable = False
# Print details of different layers

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 43s 1us/step
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 20024384 (76.39 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________

# %%
# define content model
content_layer = 'block5_conv2'
content_model = Model(
	inputs=model.input,
	outputs=model.get_layer(content_layer).output
)
content_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
# =================================================================
# Total params: 15304768 (58.38 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 15304768 (58.38 MB)
# _________________________________________________________________

# %%
# define style model
style_layers = [
	'block1_conv1',
	'block3_conv1',
	'block5_conv1'
]
style_models = [Model(inputs=model.input,
					outputs=model.get_layer(layer).output) for layer in style_layers]

# %%
# Content loss
def content_loss(content, generated):
	a_C = content_model(content)
	a_G = content_model(generated) # Add this line to compute a_G
	loss = tf.reduce_mean(tf.square(a_C - a_G))
	return loss

# %%
# gram matrix
def gram_matrix(A):
	channels = int(A.shape[-1])
	a = tf.reshape(A, [-1, channels])
	n = tf.shape(a)[0]
	gram = tf.matmul(a, a, transpose_a=True)
	return gram / tf.cast(n, tf.float32)


weight_of_layer = 1. / len(style_models)

# %%
#style loss
def style_cost(style, generated):
	J_style = 0

	for style_model in style_models:
		a_S = style_model(style)
		a_G = style_model(generated)
		GS = gram_matrix(a_S)
		GG = gram_matrix(a_G)
		content_cost = tf.reduce_mean(tf.square(GS - GG))
		J_style += content_cost * weight_of_layer

	return J_style

# %%
#content loss
def content_cost(style, generated):
	J_content = 0

	for style_model in style_models:
		a_S = style_model(style)
		a_G = style_model(generated)
		GS = gram_matrix(a_S)
		GG = gram_matrix(a_G)
		content_cost = tf.reduce_mean(tf.square(GS - GG))
		J_content += content_cost * weight_of_layer

	return J_content

# %%
import time
import math
import tensorflow as tf

generated_images = []

def training_loop(content_path, style_path, iterations=50, a=10, b=1000):
    # Load content and style images from their respective path
    content = load_and_process_image(content_path)
    style = load_and_process_image(style_path)
    generated = tf.Variable(content, dtype=tf.float32)

    opt = tf.keras.optimizers.Adam(learning_rate=7)

    best_cost = math.inf
    best_image = None
    
    for i in range(iterations):
        start_time_cpu = time.process_time()
        start_time_wall = time.time()
        
        with tf.GradientTape() as tape:
            J_content = content_cost(style, generated)
            J_style = style_cost(style, generated)
            J_total = a * J_content + b * J_style

        grads = tape.gradient(J_total, generated)
        opt.apply_gradients([(grads, generated)])

        end_time_cpu = time.process_time()  # Record end time for CPU
        end_time_wall = time.time()  # Record end time for wall time
        
        cpu_time = end_time_cpu - start_time_cpu  # Calculate CPU time
        wall_time = end_time_wall - start_time_wall  # Calculate wall time

        if J_total < best_cost:
            best_cost = J_total
            best_image = generated.numpy()

        print("CPU times: user {:.2f} ms, sys: {:.2f} ms, total: {:.2f} ms".format(
            cpu_time * 1000, 
            (end_time_cpu - start_time_cpu) * 1000, 
            (end_time_cpu - start_time_cpu + 1e-6) * 1000)
        )

        print("Wall time: {:.2f} ms".format(wall_time * 1000))
        print("Iteration: {}".format(i))
        print('Total Loss: {:.6e}.'.format(J_total))
        
        generated_images.append(generated.numpy())

    return best_image

# %%
final_img = training_loop(content_path, style_path)
# Out:
# CPU times: user 233250.00 ms, sys: 233250.00 ms, total: 233250.00 ms
# Wall time: 135675.70 ms
# Iteration: 0
# Total Loss: 4.582239e+11.
# CPU times: user 222812.50 ms, sys: 222812.50 ms, total: 222812.50 ms
# Wall time: 128663.92 ms
# Iteration: 1
# Total Loss: 3.113243e+11.
# CPU times: user 215281.25 ms, sys: 215281.25 ms, total: 215281.25 ms
# Wall time: 143840.05 ms
# Iteration: 2
# Total Loss: 1.852609e+11.
# CPU times: user 222765.62 ms, sys: 222765.62 ms, total: 222765.63 ms
# Wall time: 125534.37 ms
# Iteration: 3
# Total Loss: 1.519092e+11.
# CPU times: user 222671.88 ms, sys: 222671.88 ms, total: 222671.88 ms
# Wall time: 125511.36 ms
# Iteration: 4
# Total Loss: 1.413674e+11.
# CPU times: user 219937.50 ms, sys: 219937.50 ms, total: 219937.50 ms
# Wall time: 123333.38 ms
# Iteration: 5
# Total Loss: 1.074964e+11.
# CPU times: user 222265.62 ms, sys: 222265.62 ms, total: 222265.63 ms
# Wall time: 122594.05 ms
# Iteration: 6
# Total Loss: 7.990615e+10.
# CPU times: user 221968.75 ms, sys: 221968.75 ms, total: 221968.75 ms
# Wall time: 131416.35 ms
# Iteration: 7
# Total Loss: 6.531840e+10.
# CPU times: user 224500.00 ms, sys: 224500.00 ms, total: 224500.00 ms
# Wall time: 132368.29 ms
# Iteration: 8
# Total Loss: 5.652457e+10.
# CPU times: user 225531.25 ms, sys: 225531.25 ms, total: 225531.25 ms
# Wall time: 128518.89 ms
# Iteration: 9
# Total Loss: 4.925964e+10.
# CPU times: user 206578.12 ms, sys: 206578.12 ms, total: 206578.13 ms
# Wall time: 124743.44 ms
# Iteration: 10
# Total Loss: 4.355922e+10.
# CPU times: user 225968.75 ms, sys: 225968.75 ms, total: 225968.75 ms
# Wall time: 130584.56 ms
# Iteration: 11
# Total Loss: 3.943099e+10.
# CPU times: user 221375.00 ms, sys: 221375.00 ms, total: 221375.00 ms
# Wall time: 123789.82 ms
# Iteration: 12
# Total Loss: 3.550395e+10.
# CPU times: user 225562.50 ms, sys: 225562.50 ms, total: 225562.50 ms
# Wall time: 132105.07 ms
# Iteration: 13
# Total Loss: 3.114483e+10.
# CPU times: user 223375.00 ms, sys: 223375.00 ms, total: 223375.00 ms
# Wall time: 130531.36 ms
# Iteration: 14
# Total Loss: 2.700100e+10.
# CPU times: user 232203.12 ms, sys: 232203.12 ms, total: 232203.13 ms
# Wall time: 132005.67 ms
# Iteration: 15
# Total Loss: 2.360551e+10.
# CPU times: user 223140.62 ms, sys: 223140.62 ms, total: 223140.63 ms
# Wall time: 124338.41 ms
# Iteration: 16
# Total Loss: 2.102826e+10.
# CPU times: user 228078.12 ms, sys: 228078.12 ms, total: 228078.13 ms
# Wall time: 125564.40 ms
# Iteration: 17
# Total Loss: 1.907060e+10.
# CPU times: user 224640.62 ms, sys: 224640.62 ms, total: 224640.63 ms
# Wall time: 128706.02 ms
# Iteration: 18
# Total Loss: 1.749829e+10.
# CPU times: user 228062.50 ms, sys: 228062.50 ms, total: 228062.50 ms
# Wall time: 124429.45 ms
# Iteration: 19
# Total Loss: 1.617802e+10.
# CPU times: user 226703.12 ms, sys: 226703.12 ms, total: 226703.13 ms
# Wall time: 124327.71 ms
# Iteration: 20
# Total Loss: 1.504857e+10.
# CPU times: user 220453.12 ms, sys: 220453.12 ms, total: 220453.13 ms
# Wall time: 127137.83 ms
# Iteration: 21
# Total Loss: 1.401958e+10.
# CPU times: user 227343.75 ms, sys: 227343.75 ms, total: 227343.75 ms
# Wall time: 125177.34 ms
# Iteration: 22
# Total Loss: 1.298339e+10.
# CPU times: user 225031.25 ms, sys: 225031.25 ms, total: 225031.25 ms
# Wall time: 125967.13 ms
# Iteration: 23
# Total Loss: 1.193064e+10.
# CPU times: user 231203.12 ms, sys: 231203.12 ms, total: 231203.13 ms
# Wall time: 125625.06 ms
# Iteration: 24
# Total Loss: 1.094573e+10.
# CPU times: user 233500.00 ms, sys: 233500.00 ms, total: 233500.00 ms
# Wall time: 124293.28 ms
# Iteration: 25
# Total Loss: 1.009946e+10.
# CPU times: user 226984.38 ms, sys: 226984.38 ms, total: 226984.38 ms
# Wall time: 123029.80 ms
# Iteration: 26
# Total Loss: 9.380759e+09.
# CPU times: user 226953.12 ms, sys: 226953.12 ms, total: 226953.13 ms
# Wall time: 121023.48 ms
# Iteration: 27
# Total Loss: 8.738629e+09.
# CPU times: user 218093.75 ms, sys: 218093.75 ms, total: 218093.75 ms
# Wall time: 119937.40 ms
# Iteration: 28
# Total Loss: 8.150177e+09.
# CPU times: user 225406.25 ms, sys: 225406.25 ms, total: 225406.25 ms
# Wall time: 138350.72 ms
# Iteration: 29
# Total Loss: 7.639175e+09.
# CPU times: user 217625.00 ms, sys: 217625.00 ms, total: 217625.00 ms
# Wall time: 129960.12 ms
# Iteration: 30
# Total Loss: 7.206904e+09.
# CPU times: user 222546.88 ms, sys: 222546.88 ms, total: 222546.88 ms
# Wall time: 136023.03 ms
# Iteration: 31
# Total Loss: 6.793741e+09.
# CPU times: user 222328.12 ms, sys: 222328.12 ms, total: 222328.13 ms
# Wall time: 132789.31 ms
# Iteration: 32
# Total Loss: 6.370251e+09.
# CPU times: user 220953.12 ms, sys: 220953.12 ms, total: 220953.13 ms
# Wall time: 131161.72 ms
# Iteration: 33
# Total Loss: 5.971593e+09.
# CPU times: user 223015.62 ms, sys: 223015.62 ms, total: 223015.63 ms
# Wall time: 130602.00 ms
# Iteration: 34
# Total Loss: 5.617527e+09.
# CPU times: user 231375.00 ms, sys: 231375.00 ms, total: 231375.00 ms
# Wall time: 132845.91 ms
# Iteration: 35
# Total Loss: 5.301019e+09.
# CPU times: user 224218.75 ms, sys: 224218.75 ms, total: 224218.75 ms
# Wall time: 131015.85 ms
# Iteration: 36
# Total Loss: 5.027559e+09.
# CPU times: user 222015.62 ms, sys: 222015.62 ms, total: 222015.63 ms
# Wall time: 130335.52 ms
# Iteration: 37
# Total Loss: 4.784500e+09.
# CPU times: user 235937.50 ms, sys: 235937.50 ms, total: 235937.50 ms
# Wall time: 146213.60 ms
# Iteration: 38
# Total Loss: 4.544677e+09.
# CPU times: user 223671.88 ms, sys: 223671.88 ms, total: 223671.88 ms
# Wall time: 136459.41 ms
# Iteration: 39
# Total Loss: 4.322864e+09.
# CPU times: user 237312.50 ms, sys: 237312.50 ms, total: 237312.50 ms
# Wall time: 145707.77 ms
# Iteration: 40
# Total Loss: 4.135280e+09.
# CPU times: user 219953.12 ms, sys: 219953.12 ms, total: 219953.13 ms
# Wall time: 121391.63 ms
# Iteration: 41
# Total Loss: 3.953583e+09.
# CPU times: user 226062.50 ms, sys: 226062.50 ms, total: 226062.50 ms
# Wall time: 124242.55 ms
# Iteration: 42
# Total Loss: 3.767777e+09.
# CPU times: user 223500.00 ms, sys: 223500.00 ms, total: 223500.00 ms
# Wall time: 127504.95 ms
# Iteration: 43
# Total Loss: 3.598669e+09.
# CPU times: user 218625.00 ms, sys: 218625.00 ms, total: 218625.00 ms
# Wall time: 123465.69 ms
# Iteration: 44
# Total Loss: 3.449772e+09.
# CPU times: user 222406.25 ms, sys: 222406.25 ms, total: 222406.25 ms
# Wall time: 123558.92 ms
# Iteration: 45
# Total Loss: 3.314721e+09.
# CPU times: user 227359.38 ms, sys: 227359.38 ms, total: 227359.38 ms
# Wall time: 134465.21 ms
# Iteration: 46
# Total Loss: 3.188455e+09.
# CPU times: user 223187.50 ms, sys: 223187.50 ms, total: 223187.50 ms
# Wall time: 143812.84 ms
# Iteration: 47
# Total Loss: 3.064753e+09.
# CPU times: user 222390.62 ms, sys: 222390.62 ms, total: 222390.63 ms
# Wall time: 133768.27 ms
# Iteration: 48
# Total Loss: 2.951035e+09.
# CPU times: user 224250.00 ms, sys: 224250.00 ms, total: 224250.00 ms
# Wall time: 138104.66 ms
# Iteration: 49
# Total Loss: 2.849569e+09.

# %%
# code to display best generated image and last 10 intermediate results
plt.figure(figsize=(12, 12))

for i in range(10):
	plt.subplot(4, 3, i + 1)
	display_image(generated_images[i+39])
plt.show()

# plot best result
display_image(final_img)
